# %% [markdown]
# <a href="https://colab.research.google.com/github/giutrazzini/aulas-de-python-e-exercicios-/blob/main/exercicios_pythonaula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome=input(" digite seu nome ")
print(nome)
# Out:
#  digite seu nome g
# g

# %%
idade=int(input(" digite sua idade "))
print(idade+10)
# Out:
#  digite sua idade 18
# 28

# %%
cidade=input("digite sua cidade")
print("voce mora em",cidade,",")
# Out:
# digite sua cidadesp sp sp
# voce mora em sp sp sp ,

# %%
nome=input(" digite seu nome ")
print("ola,",nome,"! seja bem vindo!")
# Out:
#  digite seu nome giuliano
# ola, giuliano  ! seja bem vindo!

# %%
num=int(input(" digite seu numero "))
print("seu numero e",num)
# Out:
#  digite seu numero18
# seu numero e 18

# %%
nome="ana "
sobrenome="silva"
nomecompleto=nome+sobrenome
print(nomecompleto)
# Out:
# ana silva

# %%
Faturamento=1
print(f"Faturamento: R${Faturamento:.2f}")
# Out:
# Faturamento: R$1.00

# %%
nome="joao"
idade=20
print(f"meu nome e {nome} e tenho {idade} anos")
# Out:
# meu nome e joao e tenho 20 anos

# %%
nome=input(" digite seu nome ")
peso=input(" digite seu peso ")
idade=input(" digite seu idade ")
genero=input(" digite seu genero ")
print(f"meu nome e {nome} e tenho {idade} anos, peso {peso} e sou {genero}")
# Out:
#  digite seu nome g
#  digite seu peso 60
#  digite seu idade 18
#  digite seu genero homem
# meu nome e g e tenho 18 anos, peso 60 e sou homem

# %%
km=float(input("quantos km voce rodou?"))

valordacorrida=4.90+3*km
print(f"sua corrida custou R${valordacorrida:.2f}")
# Out:
# quantos km voce rodou?10
# sua corrida custou R$34.90

# %%
km=float(input("quantos km voce rodou?"))

print(f"sua corrida custou R${4.90+3*km:.2f}")
# Out:
# quantos km voce rodou?10
# sua corrida custou R$34.90

# %%
brinquedos=float(input("quantos brinquedos voce foi?"))

print(f"voce foi em  {brinquedos } brinquedos e  seu rombo foi de R${30+15*brinquedos:.2f}")
# Out:
# quantos brinquedos voce foi?10
# voce foi em  10.0 brinquedos e  seu rombo foi de R$180.00

# %%
capital=float(input("qual o capital?"))
taxa=float(input("qual a taxa?"))
quantidademeses=float(input("quantos meses?"))
print(f"seu capital de {capital } com taxa de {taxa} em  {quantidademeses} meses voce tera {capital*(1+taxa/100)**quantidademeses}")
# Out:
# qual o capital?1000
# qual a taxa?10
# quantos meses?10
# seu capital de 1000.0 com taxa de 10.0 em  10.0 meses voce tera 2593.7424601000025

# %%
import math
raiz=math.sqrt(25)
print(raiz)
# Out:
# 5.0

# %%
potencia=math.pow(2,4)
print(potencia)
# Out:
# 16.0

# %%
absoluto=abs(-10)
print(absoluto)
# Out:
# 10

# %%
arredondamento=round(3.75)
print(arredondamento)
# Out:
# 4

# %%
raiz=math.sqrt(3.75)
print(raiz)
seno=math.sin(3.75)
print(seno)
cos=math.cos(3.75)
print(cos)
log=math.log(3.75)
print(log)
# Out:
# 1.9364916731037085
# -0.5715613187423437
# -0.8205593573395608
# 1.3217558399823195

# %%
num=float(input("seu numero"))
potencia=math.pow(num,2)
print(potencia)
potencia3=math.pow(num,3)
print(potencia3)
raiz=math.sqrt(num)
print(raiz)
raiz3=num*1/3
print(raiz3)
# Out:
# seu numero27
# 729.0
# 19683.0
# 5.196152422706632
# 9.0
